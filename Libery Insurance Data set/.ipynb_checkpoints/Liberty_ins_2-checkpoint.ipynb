# %%
file_names=['train.csv','test.csv','sample_submission.csv']

# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_df1= pd.read_csv('train.csv')

# %%
feature_object_dtype_list=[col for col in train_df1.columns if train_df1[col].dtype == np.object]

# %%
print((feature_object_dtype_list))
# Out:
# ['T1_V4', 'T1_V5', 'T1_V6', 'T1_V7', 'T1_V8', 'T1_V9', 'T1_V11', 'T1_V12', 'T1_V15', 'T1_V16', 'T1_V17', 'T2_V3', 'T2_V5', 'T2_V11', 'T2_V12', 'T2_V13']

# %%
feature_int_dtype_list=[col for col in train_df1.columns if train_df1[col].dtype==np.int64 and (not(col == 'Id' or col == 'Hazard'))]

# %%
print(feature_int_dtype_list)
# Out:
# ['T1_V1', 'T1_V2', 'T1_V3', 'T1_V10', 'T1_V13', 'T1_V14', 'T2_V1', 'T2_V2', 'T2_V4', 'T2_V6', 'T2_V7', 'T2_V8', 'T2_V9', 'T2_V10', 'T2_V14', 'T2_V15']

# %%
T1_Num_attr_list=[col for col in feature_int_dtype_list if col.startswith('T1_')==True]

# %%
print(T1_Num_attr_list)
# Out:
# ['T1_V1', 'T1_V2', 'T1_V3', 'T1_V10', 'T1_V13', 'T1_V14']

# %%
melt_Hazard_with_T1attr=pd.melt(train_df1,id_vars='Hazard',value_vars=T1_Num_attr_list)

# %%
melt_Hazard_with_T1attr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305994 entries, 0 to 305993
# Data columns (total 3 columns):
# Hazard      305994 non-null int64
# variable    305994 non-null object
# value       305994 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 7.0+ MB

# %%
melt_Hazard_with_T1attr['variable'].astype('category')
# Out:
# 0          T1_V1
# 1          T1_V1
# 2          T1_V1
# 3          T1_V1
# 4          T1_V1
# 5          T1_V1
# 6          T1_V1
# 7          T1_V1
# 8          T1_V1
# 9          T1_V1
# 10         T1_V1
# 11         T1_V1
# 12         T1_V1
# 13         T1_V1
# 14         T1_V1
# 15         T1_V1
# 16         T1_V1
# 17         T1_V1
# 18         T1_V1
# 19         T1_V1
# 20         T1_V1
# 21         T1_V1
# 22         T1_V1
# 23         T1_V1
# 24         T1_V1
# 25         T1_V1
# 26         T1_V1
# 27         T1_V1
# 28         T1_V1
# 29         T1_V1
#            ...
# 305964    T1_V14
# 305965    T1_V14
# 305966    T1_V14
# 305967    T1_V14
# 305968    T1_V14
# 305969    T1_V14
# 305970    T1_V14
# 305971    T1_V14
# 305972    T1_V14
# 305973    T1_V14
# 305974    T1_V14
# 305975    T1_V14
# 305976    T1_V14
# 305977    T1_V14
# 305978    T1_V14
# 305979    T1_V14
# 305980    T1_V14
# 305981    T1_V14
# 305982    T1_V14
# 305983    T1_V14
# 305984    T1_V14
# 305985    T1_V14
# 305986    T1_V14
# 305987    T1_V14
# 305988    T1_V14
# 305989    T1_V14
# 305990    T1_V14
# 305991    T1_V14
# 305992    T1_V14
# 305993    T1_V14
# Name: variable, Length: 305994, dtype: category
# Categories (6, object): [T1_V1, T1_V10, T1_V13, T1_V14, T1_V2, T1_V3]

# %%
_=melt_Hazard_with_T1attr.boxplot(column='value',by='variable')

# %%
_=plt.xlabel('value')

# %%
_=plt.ylabel('count')

# %%
plt.show()

# %%
_=train_df1.plot(kind='scatter',y='Hazard',x='T1_V1',color='red')

# %%
_=train_df1.plot(kind='scatter',y='Hazard',x='T1_V3')

# %%
_=train_df1.plot(kind='scatter',y='T1_V1',x='T1_V2')

# %%
plt.show()

# %%
_=train_df1['T1_V1'].plot(kind='hist')

# %%
plt.show()

# %%
hazard=train_df1['Hazard']

# %%
_=hazard.plot(kind='hist',bins=200)

# %%
plt.show()

# %%
num_sum = train_df1[feature_int_dtype_list].sum(axis=1,numeric_only=True)

# %%
num_sum.shape
# Out:
# (50999,)

# %%
num_sum.head()
# Out:
# 0    161
# 1    216
# 2    230
# 3    202
# 4    186
# dtype: int64

# %%
train_df1[feature_int_dtype_list].head(1)
# Out:
#    T1_V1  T1_V2  T1_V3  T1_V10  T1_V13  T1_V14  T2_V1  T2_V2  T2_V4  T2_V6  \
# 0     15      3      2       7      15       1     36     11     10      2
#
#    T2_V7  T2_V8  T2_V9  T2_V10  T2_V14  T2_V15
# 0     37      1     11       6       2       2

# %%
num_sum_mean=(num_sum)/16

# %%
num_sum_mean
# Out:
# 0        10.0625
# 1        13.5000
# 2        14.3750
# 3        12.6250
# 4        11.6250
# 5        12.8750
# 6        15.5625
# 7        14.4375
# 8         7.4375
# 9        13.1875
# 10       12.9375
# 11        8.5625
# 12       10.1250
# 13       15.5625
# 14       12.0000
# 15        8.9375
# 16       11.3125
# 17       11.5625
# 18       12.1875
# 19       12.0000
# 20       13.7500
# 21       14.0000
# 22       11.1875
# 23        9.1250
# 24       13.9375
# 25        9.6250
# 26       11.5625
# 27        9.5000
# 28       11.9375
# 29       14.3125
#           ...
# 50969     9.6875
# 50970     9.3750
# 50971    11.3750
# 50972    12.0625
# 50973    11.3750
# 50974    13.1875
# 50975     8.7500
# 50976    13.3750
# 50977     9.8750
# 50978    13.0000
# 50979    12.3125
# 50980    13.5625
# 50981    12.0000
# 50982     9.0625
# 50983     8.5625
# 50984     8.8750
# 50985    12.9375
# 50986    12.1250
# 50987    13.4375
# 50988    13.3750
# 50989    13.1250
# 50990    12.0625
# 50991    11.3125
# 50992    14.3750
# 50993     7.8125
# 50994    11.9375
# 50995    12.8125
# 50996     9.0625
# 50997    11.5000
# 50998    11.4375
# Length: 50999, dtype: float64

# %%
_=plt.plot(x=num_sum_mean,y=hazard,marker='.',linestyle='none')

# %%
hazard.head()
# Out:
# 0    1
# 1    4
# 2    1
# 3    1
# 4    1
# Name: Hazard, dtype: int64

# %%
num_sum_mean.head()
# Out:
# 0    10.0625
# 1    13.5000
# 2    14.3750
# 3    12.6250
# 4    11.6250
# dtype: float64

# %%
train_df1['Mean_num_sumCol']=num_sum_mean

# %%
train_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50999 entries, 0 to 50998
# Data columns (total 35 columns):
# Id                 50999 non-null int64
# Hazard             50999 non-null int64
# T1_V1              50999 non-null int64
# T1_V2              50999 non-null int64
# T1_V3              50999 non-null int64
# T1_V4              50999 non-null object
# T1_V5              50999 non-null object
# T1_V6              50999 non-null object
# T1_V7              50999 non-null object
# T1_V8              50999 non-null object
# T1_V9              50999 non-null object
# T1_V10             50999 non-null int64
# T1_V11             50999 non-null object
# T1_V12             50999 non-null object
# T1_V13             50999 non-null int64
# T1_V14             50999 non-null int64
# T1_V15             50999 non-null object
# T1_V16             50999 non-null object
# T1_V17             50999 non-null object
# T2_V1              50999 non-null int64
# T2_V2              50999 non-null int64
# T2_V3              50999 non-null object
# T2_V4              50999 non-null int64
# T2_V5              50999 non-null object
# T2_V6              50999 non-null int64
# T2_V7              50999 non-null int64
# T2_V8              50999 non-null int64
# T2_V9              50999 non-null int64
# T2_V10             50999 non-null int64
# T2_V11             50999 non-null object
# T2_V12             50999 non-null object
# T2_V13             50999 non-null object
# T2_V14             50999 non-null int64
# T2_V15             50999 non-null int64
# Mean_num_sumCol    50999 non-null float64
# dtypes: float64(1), int64(18), object(16)
# memory usage: 13.6+ MB

# %%
_=sns.lmplot(x='Hazard',y='Mean_num_sumCol',data=train_df1,hue='T1_V4',palette='Set1')
plt.show()

# %%
for col in feature_object_dtype_list:
    _=sns.swarmplot(x=col,y='Hazard',data=train_df1)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-119-5d8c01bb79cd> in <module>()
#       1 for col in feature_object_dtype_list:
# ----> 2     _=sns.swarmplot(x=col,y='Hazard',data=train_df1)
#       3     plt.show()
#
# C:\Anaconda\envs\biopy\lib\site-packages\seaborn\categorical.py in swarmplot(x, y, hue, data, order, hue_order, dodge, orient, color, palette, size, edgecolor, linewidth, ax, **kwargs)
#    2798                        linewidth=linewidth))
#    2799
# -> 2800     plotter.plot(ax, kwargs)
#    2801     return ax
#    2802
#
# C:\Anaconda\envs\biopy\lib\site-packages\seaborn\categorical.py in plot(self, ax, kws)
#    1433     def plot(self, ax, kws):
#    1434         """Make the full plot."""
# -> 1435         self.draw_swarmplot(ax, kws)
#    1436         self.add_legend_data(ax)
#    1437         self.annotate_axes(ax)
#
# C:\Anaconda\envs\biopy\lib\site-packages\seaborn\categorical.py in draw_swarmplot(self, ax, kws)
#    1429         for center, swarm in zip(centers, swarms):
#    1430             if swarm.get_offsets().size:
# -> 1431                 self.swarm_points(ax, swarm, center, width, s, **kws)
#    1432
#    1433     def plot(self, ax, kws):
#
# C:\Anaconda\envs\biopy\lib\site-packages\seaborn\categorical.py in swarm_points(self, ax, points, center, width, s, **kws)
#    1338
#    1339         # Do the beeswarm in point coordinates
# -> 1340         new_xy = self.beeswarm(orig_xy, d)
#    1341
#    1342         # Transform the point coordinates back to data coordinates
#
# C:\Anaconda\envs\biopy\lib\site-packages\seaborn\categorical.py in beeswarm(self, orig_xy, d)
#    1300             # Find the first candidate that doesn't overlap any neighbours
#    1301             new_xy_i = self.first_non_overlapping_candidate(candidates,
# -> 1302                                                             neighbors, d)
#    1303
#    1304             # Place it into the swarm
#
# C:\Anaconda\envs\biopy\lib\site-packages\seaborn\categorical.py in first_non_overlapping_candidate(self, candidates, neighbors, d)
#    1258             dy = neighbors_y - y_i
#    1259
# -> 1260             sq_distances = np.power(dx, 2.0) + np.power(dy, 2.0)
#    1261
#    1262             # good candidate does not overlap any of neighbors
#
# KeyboardInterrupt:

# %%
for col in feature_int_dtype_list:
    _=sns.jointplot(x=col,y='Hazard',data=train_df1)
    plt.show()

# %%
def ecdf(data):
    n = len(data)
    x=np.sort(data)
    y=np.arange(1,n+1)/n
    
    return x,y

# %%
tau=np.mean(hazard)
s=len(hazard)
Theor_=np.random.exponential(tau,s)
X,Y = ecdf(hazard)
Xthe,Ythe=ecdf(Theor_)
_=plt.plot(X,Y,marker='.',linestyle='None',color='red')
_=plt.plot(Xthe,Ythe,marker='.',linestyle='none',color='blue')

_=plt.margins(0.02)
_=plt.xlabel('Hazard Values')
_=plt.ylabel('CDF')
sample_half=np.random.exponential(tau/2,s)
sample_double=np.random.exponential(tau*2,s)
x_half,y_half=ecdf(sample_half)
x_double,y_double=ecdf(sample_double)
_ = plt.plot(x_half, y_half)
_ = plt.plot(x_double, y_double)

# %%
plt.show()

# %%
def permutation_sample(data1, data2):
    """Generate a permutation sample from two data sets."""

    # Concatenate the data sets: data
    data = np.concatenate((data1,data2))

    # Permute the concatenated array: permuted_data
    permuted_data = np.random.permutation(data)

    # Split the permuted array into two: perm_sample_1, perm_sample_2
    perm_sample_1 = permuted_data[:len(data1)]
    perm_sample_2 = permuted_data[len(data1):]

    return perm_sample_1, perm_sample_2

# %%
def draw_perm_reps(data_1, data_2, func, size=1):
    """Generate multiple permutation replicates."""

    # Initialize array of replicates: perm_replicates
    perm_replicates = np.empty(size)

    for i in range(size):
        # Generate permutation sample
        perm_sample_1, perm_sample_2 = permutation_sample(data_1,data_2)

        # Compute the test statistic
        perm_replicates[i] = func(perm_sample_1,perm_sample_2)

    return perm_replicates

# %%
train_df1['Hazard'].describe()
# Out:
# count    50999.000000
# mean         4.022785
# std          4.021194
# min          1.000000
# 25%          1.000000
# 50%          3.000000
# 75%          5.000000
# max         69.000000
# Name: Hazard, dtype: float64

# %%
train_df1['Hazard'].median()
# Out:
# 3.0

# %%
_=sns.violinplot(y='Hazard',data=train_df1)
plt.ylabel('Hazard')
plt.show()

# %%
train_df1['Insurability'] = train_df1['Hazard']<=train_df1['Hazard'].median()

# %%
train_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50999 entries, 0 to 50998
# Data columns (total 36 columns):
# Id                 50999 non-null int64
# Hazard             50999 non-null int64
# T1_V1              50999 non-null int64
# T1_V2              50999 non-null int64
# T1_V3              50999 non-null int64
# T1_V4              50999 non-null object
# T1_V5              50999 non-null object
# T1_V6              50999 non-null object
# T1_V7              50999 non-null object
# T1_V8              50999 non-null object
# T1_V9              50999 non-null object
# T1_V10             50999 non-null int64
# T1_V11             50999 non-null object
# T1_V12             50999 non-null object
# T1_V13             50999 non-null int64
# T1_V14             50999 non-null int64
# T1_V15             50999 non-null object
# T1_V16             50999 non-null object
# T1_V17             50999 non-null object
# T2_V1              50999 non-null int64
# T2_V2              50999 non-null int64
# T2_V3              50999 non-null object
# T2_V4              50999 non-null int64
# T2_V5              50999 non-null object
# T2_V6              50999 non-null int64
# T2_V7              50999 non-null int64
# T2_V8              50999 non-null int64
# T2_V9              50999 non-null int64
# T2_V10             50999 non-null int64
# T2_V11             50999 non-null object
# T2_V12             50999 non-null object
# T2_V13             50999 non-null object
# T2_V14             50999 non-null int64
# T2_V15             50999 non-null int64
# Mean_num_sumCol    50999 non-null float64
# Insurability       50999 non-null bool
# dtypes: bool(1), float64(1), int64(18), object(16)
# memory usage: 13.7+ MB

# %%
samples1=train_df1['Insurability']
samples2=np.random.exponential(4.0227847604855,51000)

# %%
np.sum(samples1)
# Out:
# 27151

# %%
new_sam2=np.array([0 if i < 3 else 1 for i in list(samples2)])

# %%
def frac_less_hazard(data_1,data_2):
    frac =np.sum(data_1)/len(data_1)
    return frac

# %%
observed_probability=frac_less_hazard(samples1,new_sam2)
print(observed_probability)
# Out:
# 0.532382987902

# %%
perm_replicates= draw_perm_reps(samples1,new_sam2,frac_less_hazard,10000)
p = np.sum(perm_replicates > observed_probability)/10000
print(p)
# Out:
# 0.0

# %%
print('The probabilty that insurabiltity of the house is dependent on the inspection'+str(p))
# Out:
# The probabilty that insurabiltity of the house is dependent on the inspection0.0

# %%
_=sns.swarmplot(x='T1_V15',y='Hazard',data = train_df1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-117-e1fb93b6f1ea> in <module>()
# ----> 1 _=sns.swarmplot(x='T1_V15',y='Hazard',data = train_df1)
#       2 plt.show()
#
# C:\Anaconda\envs\biopy\lib\site-packages\seaborn\categorical.py in swarmplot(x, y, hue, data, order, hue_order, dodge, orient, color, palette, size, edgecolor, linewidth, ax, **kwargs)
#    2798                        linewidth=linewidth))
#    2799
# -> 2800     plotter.plot(ax, kwargs)
#    2801     return ax
#    2802
#
# C:\Anaconda\envs\biopy\lib\site-packages\seaborn\categorical.py in plot(self, ax, kws)
#    1433     def plot(self, ax, kws):
#    1434         """Make the full plot."""
# -> 1435         self.draw_swarmplot(ax, kws)
#    1436         self.add_legend_data(ax)
#    1437         self.annotate_axes(ax)
#
# C:\Anaconda\envs\biopy\lib\site-packages\seaborn\categorical.py in draw_swarmplot(self, ax, kws)
#    1429         for center, swarm in zip(centers, swarms):
#    1430             if swarm.get_offsets().size:
# -> 1431                 self.swarm_points(ax, swarm, center, width, s, **kws)
#    1432
#    1433     def plot(self, ax, kws):
#
# C:\Anaconda\envs\biopy\lib\site-packages\seaborn\categorical.py in swarm_points(self, ax, points, center, width, s, **kws)
#    1338
#    1339         # Do the beeswarm in point coordinates
# -> 1340         new_xy = self.beeswarm(orig_xy, d)
#    1341
#    1342         # Transform the point coordinates back to data coordinates
#
# C:\Anaconda\envs\biopy\lib\site-packages\seaborn\categorical.py in beeswarm(self, orig_xy, d)
#    1300             # Find the first candidate that doesn't overlap any neighbours
#    1301             new_xy_i = self.first_non_overlapping_candidate(candidates,
# -> 1302                                                             neighbors, d)
#    1303
#    1304             # Place it into the swarm
#
# C:\Anaconda\envs\biopy\lib\site-packages\seaborn\categorical.py in first_non_overlapping_candidate(self, candidates, neighbors, d)
#    1258             dy = neighbors_y - y_i
#    1259
# -> 1260             sq_distances = np.power(dx, 2.0) + np.power(dy, 2.0)
#    1261
#    1262             # good candidate does not overlap any of neighbors
#
# KeyboardInterrupt:
